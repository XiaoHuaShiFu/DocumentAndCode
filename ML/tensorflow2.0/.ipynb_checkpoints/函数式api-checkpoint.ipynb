# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
(train_image, train_label), (test_image, test_label) = tf.keras.datasets.fashion_mnist.load_data()

# %%
train_image = train_image / 255.0
test_image = test_image / 255.0

# %%
input = keras.Input(shape=(28,28))

# %%
x = keras.layers.Flatten()(input)

# %%
x = keras.layers.Dense(32, activation='relu')(x)

# %%
x = keras.layers.Dropout(0.5)(x)

# %%
x = keras.layers.Dense(64, activation='relu')(x)

# %%
output = keras.layers.Dense(10, activation='softmax')(x)

# %%
model = keras.Model(inputs=input, outputs=output)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28)]          0
# _________________________________________________________________
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                25120
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 27,882
# Trainable params: 27,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_image, train_label, epochs=30, validation_data=(test_image, test_label))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/30
# 60000/60000 [==============================] - 8s 132us/sample - loss: 0.8494 - accuracy: 0.6818 - val_loss: 0.5532 - val_accuracy: 0.8025
# Epoch 2/30
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.6430 - accuracy: 0.7636 - val_loss: 0.5204 - val_accuracy: 0.8074
# Epoch 3/30
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.5984 - accuracy: 0.7804 - val_loss: 0.5406 - val_accuracy: 0.8138
# Epoch 4/30
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.5714 - accuracy: 0.7941 - val_loss: 0.5272 - val_accuracy: 0.8095
# Epoch 5/30
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.5547 - accuracy: 0.7984 - val_loss: 0.5367 - val_accuracy: 0.8061
# Epoch 6/30
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.5435 - accuracy: 0.8026 - val_loss: 0.5964 - val_accuracy: 0.7619
# Epoch 7/30
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.5295 - accuracy: 0.8093 - val_loss: 0.5411 - val_accuracy: 0.7931
# Epoch 8/30
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.5213 - accuracy: 0.8124 - val_loss: 0.5706 - val_accuracy: 0.7785
# Epoch 9/30
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.5156 - accuracy: 0.8145 - val_loss: 0.5563 - val_accuracy: 0.7928
# Epoch 10/30
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.5112 - accuracy: 0.8150 - val_loss: 0.5361 - val_accuracy: 0.7970
# Epoch 11/30
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.5007 - accuracy: 0.8200 - val_loss: 0.5664 - val_accuracy: 0.7857
# Epoch 12/30
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.5009 - accuracy: 0.8190 - val_loss: 0.5299 - val_accuracy: 0.8107
# Epoch 13/30
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.4969 - accuracy: 0.8224 - val_loss: 0.5625 - val_accuracy: 0.7766
# Epoch 14/30
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.4913 - accuracy: 0.8229 - val_loss: 0.5466 - val_accuracy: 0.7950
# Epoch 15/30
# 60000/60000 [==============================] - 7s 119us/sample - loss: 0.4856 - accuracy: 0.8258 - val_loss: 0.5491 - val_accuracy: 0.7940
# Epoch 16/30
# 60000/60000 [==============================] - 7s 116us/sample - loss: 0.4891 - accuracy: 0.8257 - val_loss: 0.5517 - val_accuracy: 0.7825
# Epoch 17/30
# 60000/60000 [==============================] - 7s 120us/sample - loss: 0.4840 - accuracy: 0.8263 - val_loss: 0.5737 - val_accuracy: 0.7747
# Epoch 18/30
# 60000/60000 [==============================] - 6s 103us/sample - loss: 0.4788 - accuracy: 0.8270 - val_loss: 0.5175 - val_accuracy: 0.8200
# Epoch 19/30
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.4830 - accuracy: 0.8269 - val_loss: 0.5617 - val_accuracy: 0.7880
# Epoch 20/30
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.4786 - accuracy: 0.8286 - val_loss: 0.5517 - val_accuracy: 0.7925
# Epoch 21/30
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.4760 - accuracy: 0.8277 - val_loss: 0.5191 - val_accuracy: 0.8076
# Epoch 22/30
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.4770 - accuracy: 0.8278 - val_loss: 0.5433 - val_accuracy: 0.8045
# Epoch 23/30
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.4723 - accuracy: 0.8284 - val_loss: 0.5298 - val_accuracy: 0.8047
# Epoch 24/30
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.4672 - accuracy: 0.8307 - val_loss: 0.5861 - val_accuracy: 0.7783
# Epoch 25/30
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.4670 - accuracy: 0.8304 - val_loss: 0.5296 - val_accuracy: 0.8074
# Epoch 26/30
# 60000/60000 [==============================] - 6s 98us/sample - loss: 0.4642 - accuracy: 0.8331 - val_loss: 0.5384 - val_accuracy: 0.8035
# Epoch 27/30
# 60000/60000 [==============================] - 5s 91us/sample - loss: 0.4669 - accuracy: 0.8309 - val_loss: 0.5402 - val_accuracy: 0.8010
# Epoch 28/30
# 60000/60000 [==============================] - 5s 89us/sample - loss: 0.4632 - accuracy: 0.8319 - val_loss: 0.5128 - val_accuracy: 0.8141
# Epoch 29/30
# 60000/60000 [==============================] - 5s 89us/sample - loss: 0.4680 - accuracy: 0.8308 - val_loss: 0.5262 - val_accuracy: 0.8118
# Epoch 30/30
# 60000/60000 [==============================] - 5s 90us/sample - loss: 0.4655 - accuracy: 0.8311 - val_loss: 0.5104 - val_accuracy: 0.8169

# %%
test_loss, test_acc = model.evaluate(test_image, test_label)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
